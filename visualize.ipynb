# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
from utils import *
from visualizer import *

# %%
#Input the file that is going to be loaded
match_win_rate = torch.load("results/gatv2-2layer/0.pt")
helper = WinRateVHelper(match_win_rate)

# %%
helper.visualize_tensor_range(end=299,start=0)

# %%
helper.visualize_tensor_range_label(end=399,start=0)

# %%
helper.visualize_tensor_range_label(end=799,start=400)

# %%
helper.visualize_tensor_range_label(end=1199,start=800)

# %%
helper.visualize_tensor_range_label(end=1599,start=1200)

# %%
helper.visualize_tensor_range_label(end=1999,start=1600)

# %%
helper.visualize_tensor_range_label(end=2399,start=2000)

# %%
helper.visualize_tensor_range_label(end=2799,start=2400)

# %%
helper.visualize_tensor_range_label(end=3199,start=2800)

# %%
helper.visualize_tensor_range_label(end=3599,start=3200)

# %%
helper.visualize_tensor_range_label(end=3999,start=3600)

# %%
helper.visualize_tensor_range_label(end=4399,start=4000)

# %%
helper.visualize_tensor_range_label(end=4500,start=4400)

# %%
helper.visualize_tensor_range_label_change_rate(group=GROUP.Home, end=299,start=0)

# %%
helper.visualize_tensor_range_label_change_rate(group=GROUP.Draw, end=299,start=0)

# %%
helper.visualize_tensor_range_label_change_rate(group=GROUP.Away, end=299,start=0)

# %%
# To show the position of player in a specific time
# It might take around 1.5 minutes to load data
# filename = "data_finalized.pickle"
# data = load_data(filename)
# helper2 = PlayerPositionVHelper(get_location_data(data, 0), 200, 200)
# Out:
# reading
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7320/1355328522.py in <module>
#       2 # It might take around 1.5 minutes to load data
#       3 filename = "data_finalized.pickle"
# ----> 4 data = load_data(filename)
#       5 helper2 = PlayerPositionVHelper(get_location_data(data, 0), 200, 200)
#
# c:\Users\Tim\Documents\HKUST\yr3fall\comp4222\comp4222-project\utils.py in load_data(filename)
#      15         while True:
#      16             try:
# ---> 17                 data=pickle.load(openfile)
#      18             except EOFError:
#      19                 break
#
# c:\Users\Tim\anaconda3\lib\site-packages\torch\storage.py in _load_from_bytes(b)
#     179
#     180 def _load_from_bytes(b):
# --> 181     return torch.load(io.BytesIO(b))
#     182
#     183
#
# ...

# %%
# print(helper2.time)
# helper2.visualize_tensor(3, True)
# Out:
# 4444

# %%
# abc = []
# x = len(data[0].gamestates)
# print(x)
# for i in range(x):
#     abc.append(data[0].gamestates[i].label)
# #print(abc)
# helper3 = ActualWinRate(abc)
# helper3.visualize_tensor_range_label()
# Out:
# 4740
# 4740

# %%
# helper3.visualize_by_range(0, helper3.time)

# %%
# Example 
# 這是train data的
match_win_rate6 = torch.load("results/gatv2-4layer/0.pt")
helper6 = WinRateVHelper(match_win_rate6)
helper6.visualize_tensor_range_label(end=300, start=0)
# 這是test data的
match_win_rate7 = torch.load("results/gatv2-4layer/49.pt")
helper7 = WinRateVHelper(match_win_rate7)
helper7.visualize_tensor_range_label(end=300, start=0)
